# %%
number=int(input('Enter number: '))

if number==0:
    print('Zero')
elif number%2==0:
    print('Even')
else:
    print('Odd')
# Out:
# [3, 4]

# %%
for i in range(2, 2):
    print(i)

# %%
prime_list=[]
n=int(input('Enter number: '))
for i in range(2, n+1):
    for k in range(2, i):
        if i%k!=0:
            prime_list.append(i)
print(prime_list)
# Out:
# [3, 4, 5, 5, 5, 6, 6, 7, 7, 7, 7, 7, 8, 8, 8, 8, 9, 9, 9, 9, 9, 9, 10, 10, 10, 10, 10, 10, 11, 11, 11, 11, 11, 11, 11, 11, 11, 12, 12, 12, 12, 12, 12]

# %%
prime_list=[]
# n=int(input('Enter number: '))
n=5

# %%
a=[]
for i in range(2, n+1):
    for k in range(2, i):
        a.append([i, k])
# Out:
# [[3, 2], [4, 2], [4, 3], [5, 2], [5, 3], [5, 4]]

# %%
for i, k in a:
    if i%k!=0
# Out:
# 3
# 4
# 4
# 5
# 5
# 5

# %%
if n==2:
    prime_list.append(2)
elif n==1:
    print('Enter bigger number')
else:
    for i in range(3, n+1):
        for k in range(2, i):
            if i%k!=0:
                prime_list.append(i)

prime_list

# %% [markdown]
# 4  2 3

# %%
n=5

# %%
nums=[1,2,2,3,3,3]
sn=str(nums)
sn.count('1')
# Out:
# 1
